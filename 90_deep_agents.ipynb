# %%
print("Hello World")
# Out:
# Hello World

# %%
import tools as custom_tools
from common import llm
web_search_tool = custom_tools.web_search

# %%
resp = web_search_tool.invoke({"query": "What is the Latest News on HDFC?"})

# %%
resp
# Out:
# {'query': 'What is the Latest News on HDFC?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.moneycontrol.com/news/tags/hdfc-bank.html',
#    'title': 'Latest & Breaking News on Hdfc Bank - Moneycontrol.com',
#    'content': 'Bank shares hit 52-week high as lender likely to appoint HDFC. HDFC Bank is now offering upto 6 per cent in FCNR-B deposit rates, Bank shares rise up to 4% on',
#    'score': 0.72278196,
#    'raw_content': None},
#   {'url': 'https://trendlyne.com/latest-news/533/HDFCBANK/hdfc-bank-ltd',
#    'title': 'HDFC Bank News, Corporate filings and Earnings/Conference Calls',
#    'content': 'HDFC Bank hikes lending rates by up to 10 bps across tenors from June 8 the Marginal Cost of funds-based Lending Rate (MCLR) by up to 10 basis points across',
#    'score': 0.6729558,
#    'raw_content': None},
#   {'url': 'https://www.hdfc.bank.in/news-room',
# ...

# %% [markdown]
# ## 1 Basic Deep Agent

# %%
import os
from typing import Literal

from tavily import TavilyClient
from deepagents import create_deep_agent

tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])


def internet_search(
    query: str,
    max_results: int = 5,
    topic: Literal["general", "news", "finance"] = "general",
    include_raw_content: bool = False,
):
    """Run a web search"""
    return tavily_client.search(
        query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic,
    )

# %%
# System prompt to steer the agent to be an expert researcher
research_instructions = """You are an expert researcher. Your job is to conduct thorough research and then write a polished report.

You have access to an internet search tool as your primary means of gathering information.

## `internet_search`

Use this to run an internet search for a given query. You can specify the max number of results to return, the topic, and whether raw content should be included.
"""

agent = create_deep_agent(
    model=llm,
    tools=[internet_search],
    system_prompt=research_instructions,
)
agent.__module__
# Out:
# 'langgraph.graph.state'

# %%
from langchain_core.messages import HumanMessage


result = agent.invoke({"messages": [HumanMessage("Give me a detailed report on HDFC Bank based on Latest News 2026.")]})

# Print the agent's response
print(result["messages"][-1].content)
# Out:
# # HDFC Bank Research Report (2025-2026)
#
# **Date:** June 12, 2026
# **Subject:** Comprehensive Analysis of Financial Performance and Strategic Positioning
# **Reporting Period:** FY 2025 – FY 2026
#
# ---
#
# ## Executive Summary
# HDFC Bank has successfully navigated the critical post-merger phase following its integration with HDFC Ltd. For the period 2025-2026, the bank has transitioned from a phase of aggressive asset growth to a balanced approach focusing on liability strengthening and digital leadership. The bank remains India's largest private sector bank by market capitalization, maintaining robust asset quality and a strong capital adequacy ratio. A significant pivot toward AI-driven banking and rural expansion has defined its strategic roadmap for 2026.
#
# ---
#
# ## 1. Financial Performance (2025-2026)
#
# ### Revenue and Profitability
# ...

# %%
result['messages']
# Out:
# [HumanMessage(content='Give me a detailed report on HDFC Bank based on Latest News 2026.', additional_kwargs={}, response_metadata={}, id='e1e28d19-91cb-4180-8d29-0b51f1e0a30d'),
# ...

# %%
result['messages']
# Out:
# [HumanMessage(content='What is the Latest News on HDFC? Give me a Report', additional_kwargs={}, response_metadata={}, id='36073159-fd94-44b7-a8ec-3c34d29e8b12'),
# ...
